# %% [markdown]
# ### Task 6 for IT-Jim Summer Internship 2020.<br>
# More about IT-Jim: https://www.it-jim.com

# %%
import numpy as np
import os
import tensorflow as tf
import tensorflow.keras as K
import matplotlib.pyplot as plt

# %%
seed = 24
batch_size = 32
num_classes = 16

# %%
classes = os.listdir('../input/miniimagenet-itjim-internship-2020-task6/dataset/train')

# %% [markdown]
# First we will build a basic fully-connected model which will just flatten an output and feedforward it through a few linear layers.

# %%
shed = K.optimizers.schedules.ExponentialDecay(
    0.01, 100000, decay_rate=0.95)
opt = K.optimizers.Adam(learning_rate=shed)

# %%
def build_fc_model(channels=3, img_size=84):
    
    inputs = K.layers.Input((img_size, img_size, channels))
    flat = K.layers.Flatten()(inputs)
    first_dense = K.layers.Dense(
        channels*img_size**2)(flat)
    first_dense = K.layers.LeakyReLU()(first_dense)
    drop = K.layers.Dropout(0.3)(first_dense)
    
    second_dense = K.layers.Dense(img_size*5)(drop)
    second_dense = K.layers.LeakyReLU()(second_dense)
    last_dense = K.layers.Dense(img_size*2)(second_dense)
    last_dense = K.layers.LeakyReLU()(last_dense)
    outputs = K.layers.Dense(num_classes, activation='softmax')(last_dense)

    model = K.models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=opt,
                    loss='categorical_crossentropy',
                    metrics=['categorical_accuracy', 
                             K.metrics.Recall(), 
                             K.metrics.Precision()])

    return model

# %% [markdown]
# Next I will try to build as close replica of CNN model as I build in pytorch and a Mini-Resnet. One issue though arisen: I think I built residual block correctly but I am not sure (and accuracy metrics suggest either I am wrong somewhere or in pytorch version I did deep-tunning(TM) ). Nevertheless, I do understand what I do in pytorch while in keras many things are hidden (or require even more explicit rewriting).

# %%
def residual_block(x):
    filters = x.shape[-1]
    y = K.layers.Conv2D(filters, (3,3), padding="same")(x)
    l_relu = K.layers.LeakyReLU()(y)
    bn = K.layers.BatchNormalization()(l_relu)
    y = K.layers.Conv2D(filters, (3, 3), padding="same")(bn)
    
    out = K.layers.Add()([x, y])
    out = K.layers.BatchNormalization()(out)
    out = K.layers.Conv2D(filters, (3, 3), padding="same")(out)
    return out

def build_cnn_model(channels=3, img_size=84):
    
    inputs = K.layers.Input((img_size, img_size, channels))
    # inputs = K.layers.Lambda(lambda x: x / 255)(inputs)

    conv1 = K.layers.Conv2D(channels, (3, 3), padding='same')(inputs)
    conv1 = K.layers.LeakyReLU()(conv1)
    conv1 = K.layers.Dropout(0.3)(conv1)
    conv2 = K.layers.Conv2D(channels*5, (3, 3), padding='same')(conv1)
    conv2 = K.layers.LeakyReLU()(conv2)
    pool1 = K.layers.MaxPooling2D((2, 2))(conv2)
    
    bottleneck = K.layers.Conv2D(channels, (3, 3), padding='same')(pool1)
    bottleneck = K.layers.LeakyReLU()(bottleneck)
    bottleneck = K.layers.Dropout(0.3)(bottleneck)
    conv_last = K.layers.Conv2D(1, (3, 3), padding='same')(bottleneck)
    conv_last = K.layers.LeakyReLU()(conv_last)
    pool2 = K.layers.MaxPooling2D((2, 2))(conv_last)
    pool2 = K.layers.Flatten()(pool2)
    outputs = K.layers.Dense(num_classes, activation='softmax')(pool2)
    
    model = K.models.Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer=opt,
                    loss='categorical_crossentropy',
                    metrics=['categorical_accuracy', K.metrics.Recall(), K.metrics.Precision()])
                  # metrics=['accuracy'])

    return model

def build_resnet_model(channels=3, img_size=84):
    
    inputs = K.layers.Input((img_size, img_size, channels))
    # inputs = K.layers.Lambda(lambda x: x / 255)(inputs)

    conv1 = K.layers.Conv2D(channels, (3, 3), padding='same')(inputs)
    conv1 = K.layers.LeakyReLU()(conv1)
    conv1 = K.layers.Dropout(0.3)(conv1)
    res = residual_block(conv1)
    conv2 = K.layers.Conv2D(channels, (3, 3), padding='same')(res)
    conv2 = K.layers.LeakyReLU()(conv2)
    pool = K.layers.MaxPooling2D((2, 2))(conv2)
    pool = K.layers.Flatten()(pool)
    outputs = K.layers.Dense(num_classes, activation='softmax')(pool)
    
    model = K.models.Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer=opt,
                    loss='categorical_crossentropy',
                    metrics=['categorical_accuracy', K.metrics.Recall(), K.metrics.Precision()])
                  # metrics=['accuracy'])

    return model

# %%
train_set = K.preprocessing.image_dataset_from_directory(
    '../input/miniimagenet-itjim-internship-2020-task6/dataset/train',
    color_mode="rgb", batch_size=batch_size, image_size=(84, 84),
    shuffle=True, seed=seed, label_mode='categorical')

val_set = K.preprocessing.image_dataset_from_directory(
    '../input/miniimagenet-itjim-internship-2020-task6/dataset/val',
    color_mode="rgb", batch_size=batch_size, image_size=(84, 84),
    shuffle=True, seed=seed, label_mode='categorical')

test_set = K.preprocessing.image_dataset_from_directory(
    '../input/miniimagenet-itjim-internship-2020-task6/dataset/test',
    color_mode="rgb", batch_size=batch_size, image_size=(84, 84),
    shuffle=True, seed=seed, label_mode='categorical')
# Out:
# Found 1120 files belonging to 16 classes.
# Found 240 files belonging to 16 classes.
# Found 240 files belonging to 16 classes.

# %%
def show_sample(dataset, grid=(4, 4)):
    fig, ax = plt.subplots(grid[0], grid[1])
    i = j = 0
    for batch in dataset.take(1):

        for x in batch:
            for c, img in enumerate(x):
                #print(img.shape)
                ax[i][j].imshow(np.uint8(img))
                ax[i][j].set_title('{}'.format(
                    classes[c]), fontsize=11)
                ax[i][j].axis('off')
                j += 1
                if j == grid[0]:
                    j = 0
                    i += 1
                if i == grid[1]:
                    break
            plt.tight_layout()
            plt.show()
            break

# %%
train_gen = K.preprocessing.image.ImageDataGenerator(
    horizontal_flip=True, rescale=1/255)
train_gen = train_gen.flow_from_directory(
        '../input/miniimagenet-itjim-internship-2020-task6/dataset/train',
        target_size=(84, 84),
        batch_size=batch_size,
        class_mode='categorical')

val_gen = K.preprocessing.image.ImageDataGenerator(
    rescale=1/255)
val_gen = val_gen.flow_from_directory(
        '../input/miniimagenet-itjim-internship-2020-task6/dataset/val',
        target_size=(84, 84),
        batch_size=batch_size,
        class_mode='categorical')

test_gen = K.preprocessing.image.ImageDataGenerator(
    rescale=1/255)
test_gen = test_gen.flow_from_directory(
        '../input/miniimagenet-itjim-internship-2020-task6/dataset/test',
        target_size=(84, 84),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 1120 images belonging to 16 classes.
# Found 240 images belonging to 16 classes.
# Found 240 images belonging to 16 classes.

# %% [markdown]
# Training FC model

# %%
epochs = 10

# %%
best_chpt = K.callbacks.ModelCheckpoint(filepath='{epoch}_{model}_best.ckpt',
                                        monitor='val_loss',
                                        mode='max',
                                        save_best_only=True, 
                                        save_weights_only=True,
                                       verbose=1)
runtime_chpt = K.callbacks.ModelCheckpoint(filepath='{epoch}_{model}_last.ckpt',
                                           monitor="val_loss",
                                           save_weights_only=True,
                                           save_freq=int(batch_size*5))

# %%
fc_model = build_fc_model()
"""
fc_history = fc_model.fit(
    train_set, steps_per_epoch=len(train_set)//batch_size, 
    epochs=epochs, validation_data=val_set)
    # callbacks=[best_chpt])
"""
fc_history = fc_model.fit_generator(
    train_gen, epochs=epochs, validation_data=val_gen,
    steps_per_epoch=len(train_gen)//batch_size)
# I might get back to checkpointing but for now it seems as a waste of time
preds = fc_model.predict(test_set)
#preds = np.argmax(probs, axis=1)
classes = train_set.class_names
#classes = [classes[x] for x in preds]
show_sample(test_set)
fc_model.save_weights('fc_model_weights.h5')
# Out:
# Epoch 1/10
# 1/1 [==============================] - 4s 4s/step - loss: 3.0078 - categorical_accuracy: 0.0625 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 5855.9497 - val_categorical_accuracy: 0.0625 - val_recall: 0.0625 - val_precision: 0.0625
# Epoch 2/10
# 1/1 [==============================] - 3s 3s/step - loss: 5113.7090 - categorical_accuracy: 0.1250 - recall: 0.1250 - precision: 0.1250 - val_loss: 44281.7031 - val_categorical_accuracy: 0.0625 - val_recall: 0.0625 - val_precision: 0.0625
# Epoch 3/10
# 1/1 [==============================] - 3s 3s/step - loss: 41594.1367 - categorical_accuracy: 0.0312 - recall: 0.0312 - precision: 0.0312 - val_loss: 66023.2812 - val_categorical_accuracy: 0.0625 - val_recall: 0.0625 - val_precision: 0.0625
# Epoch 4/10
# 1/1 [==============================] - 3s 3s/step - loss: 77100.3906 - categorical_accuracy: 0.0000e+00 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 32550.6074 - val_categorical_accuracy: 0.0625 - val_recall: 0.0625 - val_precision: 0.0625
# Epoch 5/10
# 1/1 [==============================] - 3s 3s/step - loss: 27675.2266 - categorical_accuracy: 0.0312 - recall: 0.0312 - precision: 0.0312 - val_loss: 159087.7188 - val_categorical_accuracy: 0.0625 - val_recall: 0.0625 - val_precision: 0.0625
# Epoch 6/10
# 1/1 [==============================] - 3s 3s/step - loss: 153787.8125 - categorical_accuracy: 0.0625 - recall: 0.0625 - precision: 0.0625 - val_loss: 58464.6992 - val_categorical_accuracy: 0.0625 - val_recall: 0.0625 - val_precision: 0.0625
# Epoch 7/10
# 1/1 [==============================] - 3s 3s/step - loss: 53665.9219 - categorical_accuracy: 0.1250 - recall: 0.1250 - precision: 0.1250 - val_loss: 77416.4453 - val_categorical_accuracy: 0.0625 - val_recall: 0.0625 - val_precision: 0.0625
# Epoch 8/10
# 1/1 [==============================] - 3s 3s/step - loss: 73666.7734 - categorical_accuracy: 0.0000e+00 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 106176.9766 - val_categorical_accuracy: 0.0625 - val_recall: 0.0625 - val_precision: 0.0625
# Epoch 9/10
# 1/1 [==============================] - 3s 3s/step - loss: 90335.9609 - categorical_accuracy: 0.0312 - recall: 0.0312 - precision: 0.0312 - val_loss: 95273.6797 - val_categorical_accuracy: 0.0625 - val_recall: 0.0625 - val_precision: 0.0625
# Epoch 10/10
# 1/1 [==============================] - 4s 4s/step - loss: 107455.7344 - categorical_accuracy: 0.0312 - recall: 0.0312 - precision: 0.0312 - val_loss: 80778.0938 - val_categorical_accuracy: 0.0625 - val_recall: 0.0625 - val_precision: 0.0625

# %%
cnn_model = build_cnn_model()
"""
fc_history = fc_model.fit(
    train_set, steps_per_epoch=len(train_set)//batch_size, 
    epochs=epochs, validation_data=val_set)
    # callbacks=[best_chpt])
"""
cnn_history = cnn_model.fit_generator(
    train_gen, epochs=epochs, validation_data=val_gen,
    steps_per_epoch=len(train_gen)//batch_size)
# I might get back to checkpointing but for now it seems as a waste of time
probs = cnn_model.predict(test_set)
#preds = np.argmax(probs, axis=1)
classes = train_set.class_names
#classes = [classes[x] for x in preds]
show_sample(test_set)
cnn_model.save_weights('cnn_model_weights.h5')
# Out:
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 2.8095 - categorical_accuracy: 0.0938 - recall_1: 0.0000e+00 - precision_1: 0.0000e+00 - val_loss: 2.7747 - val_categorical_accuracy: 0.0500 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00
# Epoch 2/10
# 1/1 [==============================] - 1s 683ms/step - loss: 2.7765 - categorical_accuracy: 0.0625 - recall_1: 0.0000e+00 - precision_1: 0.0000e+00 - val_loss: 2.7742 - val_categorical_accuracy: 0.0583 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00
# Epoch 3/10
# 1/1 [==============================] - 1s 618ms/step - loss: 2.7607 - categorical_accuracy: 0.1250 - recall_1: 0.0000e+00 - precision_1: 0.0000e+00 - val_loss: 2.7736 - val_categorical_accuracy: 0.0667 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00
# Epoch 4/10
# 1/1 [==============================] - 1s 509ms/step - loss: 2.7683 - categorical_accuracy: 0.0625 - recall_1: 0.0000e+00 - precision_1: 0.0000e+00 - val_loss: 2.7738 - val_categorical_accuracy: 0.0667 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00
# Epoch 5/10
# 1/1 [==============================] - 0s 495ms/step - loss: 2.7605 - categorical_accuracy: 0.0625 - recall_1: 0.0000e+00 - precision_1: 0.0000e+00 - val_loss: 2.7775 - val_categorical_accuracy: 0.0625 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00
# Epoch 6/10
# 1/1 [==============================] - 0s 478ms/step - loss: 2.8039 - categorical_accuracy: 0.0938 - recall_1: 0.0000e+00 - precision_1: 0.0000e+00 - val_loss: 2.7733 - val_categorical_accuracy: 0.0667 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00
# Epoch 7/10
# 1/1 [==============================] - 1s 512ms/step - loss: 2.8151 - categorical_accuracy: 0.0312 - recall_1: 0.0000e+00 - precision_1: 0.0000e+00 - val_loss: 2.7711 - val_categorical_accuracy: 0.0667 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00
# Epoch 8/10
# 1/1 [==============================] - 1s 593ms/step - loss: 2.7453 - categorical_accuracy: 0.0938 - recall_1: 0.0000e+00 - precision_1: 0.0000e+00 - val_loss: 2.7708 - val_categorical_accuracy: 0.0833 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00
# Epoch 9/10
# 1/1 [==============================] - 1s 508ms/step - loss: 2.7281 - categorical_accuracy: 0.0625 - recall_1: 0.0000e+00 - precision_1: 0.0000e+00 - val_loss: 2.7703 - val_categorical_accuracy: 0.0875 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00
# Epoch 10/10
# 1/1 [==============================] - 0s 496ms/step - loss: 2.7648 - categorical_accuracy: 0.0625 - recall_1: 0.0000e+00 - precision_1: 0.0000e+00 - val_loss: 2.7697 - val_categorical_accuracy: 0.0708 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00

# %%
mini_resnet = build_resnet_model()
"""
fc_history = fc_model.fit(
    train_set, steps_per_epoch=len(train_set)//batch_size, 
    epochs=epochs, validation_data=val_set)
    # callbacks=[best_chpt])
"""
res_history = mini_resnet.fit_generator(
    train_gen, epochs=epochs, validation_data=val_gen,
    steps_per_epoch=len(train_gen)//batch_size)
# I might get back to checkpointing but for now it seems as a waste of time
preds = mini_resnet.predict(test_set)
#preds = np.argmax(probs, axis=1)
classes = train_set.class_names
#classes = [classes[x] for x in preds]
show_sample(test_set)
mini_resnet.save_weights('res_model_weights.h5')
# Out:
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 3.9693 - categorical_accuracy: 0.0625 - recall_2: 0.0000e+00 - precision_2: 0.0000e+00 - val_loss: 2.8898 - val_categorical_accuracy: 0.0583 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00
# Epoch 2/10
# 1/1 [==============================] - 1s 699ms/step - loss: 15.4412 - categorical_accuracy: 0.1562 - recall_2: 0.1562 - precision_2: 0.1724 - val_loss: 2.9806 - val_categorical_accuracy: 0.0542 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00
# Epoch 3/10
# 1/1 [==============================] - 1s 735ms/step - loss: 17.6295 - categorical_accuracy: 0.0625 - recall_2: 0.0625 - precision_2: 0.0870 - val_loss: 3.1726 - val_categorical_accuracy: 0.0833 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00
# Epoch 4/10
# 1/1 [==============================] - 1s 677ms/step - loss: 20.7967 - categorical_accuracy: 0.0625 - recall_2: 0.0312 - precision_2: 0.0455 - val_loss: 2.9805 - val_categorical_accuracy: 0.0708 - val_recall_2: 0.0042 - val_precision_2: 0.5000
# Epoch 5/10
# 1/1 [==============================] - 1s 791ms/step - loss: 21.9747 - categorical_accuracy: 0.0625 - recall_2: 0.0625 - precision_2: 0.0625 - val_loss: 2.9593 - val_categorical_accuracy: 0.0750 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00
# Epoch 6/10
# 1/1 [==============================] - 1s 739ms/step - loss: 17.0011 - categorical_accuracy: 0.0938 - recall_2: 0.0938 - precision_2: 0.0968 - val_loss: 3.4432 - val_categorical_accuracy: 0.0667 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00
# Epoch 7/10
# 1/1 [==============================] - 1s 700ms/step - loss: 14.1271 - categorical_accuracy: 0.0625 - recall_2: 0.0625 - precision_2: 0.0714 - val_loss: 4.3653 - val_categorical_accuracy: 0.0625 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00
# Epoch 8/10
# 1/1 [==============================] - 1s 675ms/step - loss: 5.8378 - categorical_accuracy: 0.0938 - recall_2: 0.0938 - precision_2: 0.2000 - val_loss: 5.7913 - val_categorical_accuracy: 0.0625 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00
# Epoch 9/10
# 1/1 [==============================] - 1s 699ms/step - loss: 4.7556 - categorical_accuracy: 0.0938 - recall_2: 0.0625 - precision_2: 0.2500 - val_loss: 7.7164 - val_categorical_accuracy: 0.0625 - val_recall_2: 0.0625 - val_precision_2: 0.0625
# Epoch 10/10
# 1/1 [==============================] - 1s 690ms/step - loss: 3.7523 - categorical_accuracy: 0.1562 - recall_2: 0.0625 - precision_2: 0.4000 - val_loss: 8.9936 - val_categorical_accuracy: 0.0625 - val_recall_2: 0.0625 - val_precision_2: 0.0625

# %% [markdown]
# Questions remaining unanswered yet:
# * How model checkpoint callback of keras actually works? Trying to use one of this callbacks just causes overflow of memory.
# * How to properly modularize repitative blocks and use them afterward?
# * What is going on with CE loss with default keras 'categorical crossentropy'?
# * How long would it take to compile TF for my local machine? Inprecise answer - at least 3 days (after that I lost my patience)
#
# While I implimented many optimizations in pytorch, my knowledge of Tensorflow is limited.
